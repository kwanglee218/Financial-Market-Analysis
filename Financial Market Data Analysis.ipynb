# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Data Preparation

# %% [markdown]
# # S&P 500

# %%
df_2002 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2002.1_2002.12.csv')
df_2012 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2012.1_2012.12.csv')
df_2007 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2007.1_2007.12.csv')
df_2017 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2017.1_2017.12.csv')
df_2008 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2008.1_2008.12.csv')
df_2018 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2018.1_2018.12.csv')
df_2009 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2009.1_2009.12.csv')
df_2019 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2019.1_2019.12.csv')
df_2006 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2006.1_2006.12.csv')
df_2016 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2016.1_2016.12.csv')
df_2003 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2003.1_2003.12.csv')
df_2013 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2013.1_2013.12.csv')
df_2014 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2014.1_2014.12.csv')
df_2004 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2004.1_2004.12.csv')
df_2021 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2021.1_2021.12.csv')
df_2011 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2011.1_2011.12.csv')
df_2001 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2001.1_2001.12.csv')
df_2010 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2010.1_2010.12.csv')
df_2000 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2000.1_2000.12.csv')
df_2015 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2015.1_2015.12.csv')
df_2022 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2022.1_2022.09.csv')
df_2020 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2020.1_2020.12.csv')
df_2005 = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SnP500/2005.1_2005.12.csv')

# %%
df_sp500 = pd.concat([df_2002,df_2012,df_2007,df_2017,df_2008,df_2018,df_2009,df_2019,df_2006,
                     df_2016,df_2003,df_2013,df_2014,df_2004,df_2021,df_2011,df_2001,df_2010,df_2000,df_2015,df_2022,df_2020,df_2005])

# %%
df_sp500['Year'] = df_sp500['Date'].str.split('/', expand=True)[2]
df_sp500['Month'] = df_sp500['Date'].str.split('/', expand=True)[0]
df_sp500['Year_Month'] = df_sp500['Year'] + '_' + df_sp500['Month']
df_sp500['Category'] = 'S&P500'
df_sp500['Date'] = pd.to_datetime(df_sp500['Date'], format='%M/%d/%Y')
df_sp500['Date'] = df_sp500['Date'].dt.strftime('%Y-%M-%d')
df_sp500['Close'] = df_sp500['Close'].str.replace(',','').astype(float)
df_sp500 = df_sp500.sort_values(['Year','Month'])
df_sp500 = df_sp500[['Date','Year','Month','Year_Month','Close','Category']]
df_sp500 = df_sp500.sort_values(['Year','Date'])
df_sp500 = df_sp500.set_index('Date')
df_sp500_2019 = df_sp500[df_sp500['Year'] >= '2019']
df_sp500_2008 = df_sp500[df_sp500['Year'] >= '2008']
df_sp500_2008.head()
# Out:
#             Year Month Year_Month    Close Category
# Date
# 2008-01-02  2008    01    2008_01  1447.16   S&P500
# 2008-01-03  2008    01    2008_01  1447.16   S&P500
# 2008-01-04  2008    01    2008_01  1411.63   S&P500
# 2008-01-07  2008    01    2008_01  1416.18   S&P500
# 2008-01-08  2008    01    2008_01  1390.19   S&P500

# %% [markdown]
# # NASDAQ

# %%
df_nasdaq = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/NASDAQ.csv')

df_nasdaq['Year'] = df_nasdaq['Date'].str.split('-',expand=True)[0]
df_nasdaq['Month'] = df_nasdaq['Date'].str.split('-', expand=True)[1]
df_nasdaq['Year_Month'] = df_nasdaq['Year'] + '_' + df_nasdaq['Month']
df_nasdaq['Category'] = 'NASDAQ'
df_nasdaq = df_nasdaq.sort_values(['Year','Month'])
df_nasdaq = df_nasdaq[['Date','Year','Month','Year_Month','Close','Category']]
df_nasdaq = df_nasdaq.sort_values(['Year','Date'])
df_nasdaq = df_nasdaq.set_index('Date')
df_nasdaq_2019 = df_nasdaq[df_nasdaq['Year'] >= '2019']
df_nasdaq_2008 = df_nasdaq[df_nasdaq['Year'] >= '2008']

df_nasdaq_2008.head()
# Out:
#             Year Month Year_Month        Close Category
# Date
# 2008-01-02  2008    01    2008_01  2609.629883   NASDAQ
# 2008-01-03  2008    01    2008_01  2602.679932   NASDAQ
# 2008-01-04  2008    01    2008_01  2504.649902   NASDAQ
# 2008-01-07  2008    01    2008_01  2499.459961   NASDAQ
# 2008-01-08  2008    01    2008_01  2440.510010   NASDAQ

# %% [markdown]
# # KOSPI

# %%
df_kospi = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/kospi.csv')

df_kospi['Year'] = df_kospi['Date'].str.split('-', expand=True)[0]
df_kospi['Month'] = df_kospi['Date'].str.split('-', expand=True)[1]
df_kospi['Year_Month'] = df_kospi['Year'] + '_' + df_kospi['Month']
df_kospi['Category'] = 'kospi'
df_kospi = df_kospi.sort_values(['Year','Month'])
df_kospi = df_kospi[['Date','Year','Month','Year_Month','Close','Category']]
df_kospi = df_kospi.sort_values(['Year','Date'])
df_kospi = df_kospi.set_index('Date')
df_kospi_2019 = df_kospi[df_kospi['Year'] >= '2019']
df_kospi_2008 = df_kospi[df_kospi['Year'] >= '2008']

df_kospi_2008.head()
# Out:
#             Year Month Year_Month        Close Category
# Date
# 2008-01-02  2008    01    2008_01  1853.449951    kospi
# 2008-01-03  2008    01    2008_01  1852.729980    kospi
# 2008-01-04  2008    01    2008_01  1863.900024    kospi
# 2008-01-07  2008    01    2008_01  1831.140015    kospi
# 2008-01-08  2008    01    2008_01  1826.229980    kospi

# %% [markdown]
# # iShares 1-3 Year Treasury Bond ETF | SHY

# %%
df_SHY = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SHY.csv')

df_SHY['Year'] = df_SHY['Date'].str.split('-', expand=True)[0]
df_SHY['Month'] = df_SHY['Date'].str.split('-', expand=True)[1]
df_SHY['Year_Month'] = df_SHY['Year'] + '_' + df_SHY['Month']
df_SHY['Category'] = 'SHV_short'
df_SHY = df_SHY.sort_values(['Year','Month'])
df_SHY = df_SHY[['Date','Year','Month','Year_Month','Close','Category']]
df_SHY = df_SHY.sort_values(['Year','Date'])
df_SHY = df_SHY.set_index('Date')
df_SHY_2019 = df_SHY[df_SHY['Year'] >= '2019']
df_SHY_2008 = df_SHY[df_SHY['Year'] >= '2008']

df_SHY_2008.head()
# Out:
#             Year Month Year_Month      Close   Category
# Date
# 2008-01-02  2008    01    2008_01  82.339996  SHV_short
# 2008-01-03  2008    01    2008_01  82.470001  SHV_short
# 2008-01-04  2008    01    2008_01  82.589996  SHV_short
# 2008-01-07  2008    01    2008_01  82.540001  SHV_short
# 2008-01-08  2008    01    2008_01  82.660004  SHV_short

# %% [markdown]
# # iShares 7-10 Year Treasury Bond ETF | IEF

# %%
df_IEF = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/IEF.csv')

df_IEF['Year'] = df_IEF['Date'].str.split('-', expand=True)[0]
df_IEF['Month'] = df_IEF['Date'].str.split('-', expand=True)[1]
df_IEF['Year_Month'] = df_IEF['Year'] + '_' + df_IEF['Month']
df_IEF['Category'] = 'IEF_7_10'
df_IEF = df_IEF.sort_values(['Year','Month'])
df_IEF = df_IEF[['Date','Year','Month','Year_Month','Close','Category']]
df_IEF = df_IEF.sort_values(['Year','Date'])
df_IEF = df_IEF.set_index('Date')
df_IEF_2019 = df_IEF[df_IEF['Year'] >= '2019']
df_IEF_2008 = df_IEF[df_IEF['Year'] >= '2008']

df_IEF_2008.head()
# Out:
#             Year Month Year_Month      Close  Category
# Date
# 2008-01-02  2008    01    2008_01  87.629997  IEF_7_10
# 2008-01-03  2008    01    2008_01  87.809998  IEF_7_10
# 2008-01-04  2008    01    2008_01  88.040001  IEF_7_10
# 2008-01-07  2008    01    2008_01  88.199997  IEF_7_10
# 2008-01-08  2008    01    2008_01  88.389999  IEF_7_10

# %% [markdown]
# # SPDR Portfolio Long Term Treasury ETF | SPTL

# %%
df_SPTL = pd.read_csv('/Users/kwanghun.lee/Desktop/dataset/SPTL.csv')

df_SPTL['Year'] = df_SPTL['Date'].str.split('-', expand=True)[0]
df_SPTL['Month'] = df_SPTL['Date'].str.split('-', expand=True)[1]
df_SPTL['Year_Month'] = df_SPTL['Year'] + '_' + df_SPTL['Month']
df_SPTL['Category'] = 'SPTL_10+'
df_SPTL = df_SPTL.sort_values(['Year','Month'])
df_SPTL = df_SPTL[['Date','Year','Month','Year_Month','Close','Category']]
df_SPTL = df_SPTL.sort_values(['Year','Date'])
df_SPTL = df_SPTL.set_index('Date')
df_SPTL_2019 = df_SPTL[df_SPTL['Year'] >= '2019']
df_SPTL_2008 = df_SPTL[df_SPTL['Year'] >= '2008']

df_SPTL_2008.head()
# Out:
#             Year Month Year_Month      Close  Category
# Date
# 2008-01-02  2008    01    2008_01  27.035000  SPTL_10+
# 2008-01-03  2008    01    2008_01  26.985001  SPTL_10+
# 2008-01-04  2008    01    2008_01  27.129999  SPTL_10+
# 2008-01-07  2008    01    2008_01  27.184999  SPTL_10+
# 2008-01-08  2008    01    2008_01  27.100000  SPTL_10+

# %% [markdown]
# # USD vs. KRW Currency Rate

# %%
df_currency = pd.read_csv('USD_KRW.csv')

df_currency['Year'] = df_currency['Date'].str.split('/', expand=True)[2]
df_currency['Year'].replace({'22':'2022','21':'2021', '20':'2020', '19':'2019', '18':'2018', '17':'2017',
                             '16':'2016', '15':'2015', '14':'2014', '13':'2013', '12':'2012',
                             '11':'2011', '10':'2010', '09':'2009', '08':'2008', '07':'2007'}, inplace=True)
df_currency['Month'] = df_currency['Date'].str.split('/', expand=True)[0]
df_currency['Year_Month'] = df_currency['Year'] + '_' + df_currency['Month']
df_currency['Category'] = 'USD_KRW Rate'
df_currency['Date'] = pd.to_datetime(df_currency['Date'], format='%M/%d/%y')
df_currency['Date'] = df_currency['Date'].dt.strftime('%Y-%M-%d')
df_currency = df_currency.rename(columns={' Close':'Close'})
df_currency = df_currency.sort_values(['Year','Month'])
df_currency = df_currency.rename(columns={' Close':'Close'})
df_currency = df_currency[['Date','Year','Month','Year_Month','Close','Category']]
df_currency = df_currency.sort_values(['Year','Date'])
df_currency = df_currency.set_index('Date')
df_currency_2019 = df_currency[df_currency['Year'] >= '2019']
df_currency_2008 = df_currency[df_currency['Year'] >= '2008']

df_currency_2008.head()
# Out:
#             Year Month Year_Month   Close      Category
# Date
# 2008-01-01  2008    01    2008_01  922.00  USD_KRW Rate
# 2008-01-02  2008    01    2008_01  939.50  USD_KRW Rate
# 2008-01-03  2008    01    2008_01  935.80  USD_KRW Rate
# 2008-01-04  2008    01    2008_01  941.55  USD_KRW Rate
# 2008-01-07  2008    01    2008_01  941.55  USD_KRW Rate

# %% [markdown]
# # 2. Data Visualization

# %%
fig, ax1= plt.subplots(figsize=(10,5))

df_nasdaq_2019.groupby('Year_Month')['Close'].mean().plot(color='black',linestyle='--',label='NASDAQ',legend=True,ax=ax1)
df_kospi_2019.groupby('Year_Month')['Close'].mean().plot(color='blue',label='KOSPI',legend=True,ax=ax1)
#ax1.set_title('Economic Indicator Comparison', fontsize=20, fontweight='bold')
ax1.legend(fontsize=12, loc='upper left')
ax1.set_xlabel('Year_Month',fontsize=14)
ax1.set_ylabel('Index',fontsize=14)
ax2=ax1.twinx()
df_currency_2019.groupby('Year_Month')['Close'].mean().plot(color='red',linewidth=3,label='USD-KRW',legend=True,ax=ax2)
ax2.legend(fontsize=12, loc='upper right')
ax2.set_ylabel('Currency Rate',fontsize=14)
# Out:
# Text(0, 0.5, 'Currency Rate')

# %%
fig, ax1= plt.subplots(figsize=(20,10))

df_nasdaq_2008.groupby('Year_Month')['Close'].mean().plot(color='black',linestyle='--',label='NASDAQ',legend=True,ax=ax1)
df_kospi_2008.groupby('Year_Month')['Close'].mean().plot(color='blue',linewidth=5,label='KOSPI',legend=True,ax=ax1)
#ax1.set_title('Economic Indicator Comparison', fontsize=30, fontweight='bold')
ax1.legend(fontsize=24, loc='upper center')
ax1.set_xlabel('Year_Month',fontsize=23)
ax1.set_ylabel('Index',fontsize=23)
ax1.xaxis.set_tick_params(labelsize=15)
ax1.yaxis.set_tick_params(labelsize=15)
ax2=ax1.twinx()
df_currency_2008.groupby('Year_Month')['Close'].mean().plot(color='red',linewidth=5,label='USD-KRW',legend=True,ax=ax2)
ax2.legend(fontsize=24, loc='upper left')
ax2.set_ylabel('Currency Rate',fontsize=23)
ax2.yaxis.set_tick_params(labelsize=15)

# %%
fig, ax1= plt.subplots(figsize=(20,10))

df_kospi_2008.groupby('Year_Month')['Close'].mean().plot(color='blue',linewidth=5,label='KOSPI',legend=True,ax=ax1)
ax1.legend(fontsize=24, loc='upper center')
ax1.set_xlabel('Year_Month',fontsize=23)
ax1.set_ylabel('Index',fontsize=23)
ax1.xaxis.set_tick_params(labelsize=15)
ax1.yaxis.set_tick_params(labelsize=15)
ax2=ax1.twinx()
df_currency_2008.groupby('Year_Month')['Close'].mean().plot(color='red',linewidth=5,label='USD-KRW',legend=True,ax=ax2)
ax2.legend(fontsize=24, loc='lower center')
ax2.set_ylabel('Currency Rate',fontsize=23)
ax2.yaxis.set_tick_params(labelsize=15)

# %%
fig, ax1= plt.subplots(figsize=(20,10))

df_nasdaq_2008.groupby('Year_Month')['Close'].mean().plot(color='black',label='NASDAQ',legend=True,ax=ax1)
df_kospi_2008.groupby('Year_Month')['Close'].mean().plot(color='blue',linewidth=5,label='KOSPI',legend=True,ax=ax1)
ax1.legend(fontsize=24, loc='upper left')
ax1.set_xlabel('Year_Month',fontsize=23)
ax1.set_ylabel('Index',fontsize=23)
ax1.xaxis.set_tick_params(labelsize=15)
ax1.yaxis.set_tick_params(labelsize=15)

# %%
fig, ax1= plt.subplots(figsize=(20,10))

df_sp500_2008.groupby('Year_Month')['Close'].mean().plot(color='black',label='S&P500',legend=True,ax=ax1)
df_kospi_2008.groupby('Year_Month')['Close'].mean().plot(color='blue',linewidth=5,label='KOSPI',legend=True,ax=ax1)
ax1.legend(fontsize=24, loc='upper left')
ax1.set_xlabel('Year_Month',fontsize=23)
ax1.set_ylabel('Index',fontsize=23)
ax1.xaxis.set_tick_params(labelsize=15)
ax1.yaxis.set_tick_params(labelsize=15)
ax1=ax.twinx()

# %%
fig, ax1= plt.subplots(figsize=(20,5))

df_kospi_2008.groupby('Year_Month')['Close'].mean().plot(color='blue',linewidth=5,label='KOSPI',legend=True,ax=ax1)
ax1.legend(fontsize=24, loc='upper left')
ax1.set_xlabel('Year_Month',fontsize=23)
ax1.set_ylabel('Index',fontsize=23)
ax1.xaxis.set_tick_params(labelsize=15)
ax1.yaxis.set_tick_params(labelsize=15)

# %%
fig, ax1= plt.subplots(figsize=(20,10))

df_nasdaq_2008.groupby('Year_Month')['Close'].mean().plot(color='blue',label='NASDAQ',legend=True,ax=ax1)
df_kospi_2008.groupby('Year_Month')['Close'].mean().plot(color='red',linewidth=5,label='KOSPI',legend=True,ax=ax1)

#ax1.set_title('Economic Indicator Comparison', fontsize=30, fontweight='bold')
ax1.legend(fontsize=24, loc='upper left')
ax1.set_xlabel('Year_Month',fontsize=23)
ax1.set_ylabel('Index (KOSPI_NASDAQ)',fontsize=23)
ax1.xaxis.set_tick_params(labelsize=15)
ax1.yaxis.set_tick_params(labelsize=15)
ax2=ax1.twinx()
df_sp500_2008.groupby('Year_Month')['Close'].mean().plot(color='black',label='S&P500',legend=True,ax=ax2)

ax2.set_ylabel('Index (S&P500)',fontsize=23)
ax2.yaxis.set_tick_params(labelsize=15)
ax2.legend(fontsize=24,loc='upper center')

# %%
fig, (ax1,ax2,ax3)= plt.subplots(3,1,figsize=(15,10))

df_nasdaq_2008.groupby('Year_Month')['Close'].mean().plot(color='blue',label='NASDAQ',legend=True,ax=ax1)
#ax1.set_title('Nasdaq',fontsize=20)
ax1.legend(fontsize=20)
ax1.set_xlabel('')
ax1.set_ylabel('Index',fontsize=20)
ax1.xaxis.set_tick_params(labelsize=15)
ax1.yaxis.set_tick_params(labelsize=15)

df_kospi_2008.groupby('Year_Month')['Close'].mean().plot(color='black',label='KOSPI',legend=True,ax=ax2)
#ax2.set_title('KOSPI',fontsize=20)
ax2.legend(fontsize=20)
ax2.set_xlabel('')
ax2.set_ylabel('Index',fontsize=20)
ax2.xaxis.set_tick_params(labelsize=15)
ax2.yaxis.set_tick_params(labelsize=15)

df_currency_2008.groupby('Year_Month')['Close'].mean().plot(color='red',label='USD-KRW',legend=True,ax=ax3)
#ax3.set_title('USD-KRW Currency Rate',fontsize=20)
ax3.legend(fontsize=20,loc='upper left')
ax3.set_xlabel('')
ax3.set_ylabel('Currency Rate',fontsize=20)
ax3.xaxis.set_tick_params(labelsize=15)
ax3.yaxis.set_tick_params(labelsize=15)

# %%
fig, ax = plt.subplots(figsize=(10,5))

df_currency_2008.groupby('Year_Month')['Close'].mean().plot(color='red',label='USD-KRW',legend=True)
ax.legend(fontsize=13,loc='lower center')
ax.set_xlabel('')
ax.set_ylabel('Currency Rate',fontsize=14,color='red')
#ax.set_title('Currency Rate & KOSPI',fontsize=20,fontweight='bold')
ax1=ax.twinx()
df_kospi_2008.groupby('Year_Month')['Close'].mean().plot(color='black',label='KOSPI',legend=True)
ax1.legend(fontsize=13,loc='upper center')
ax1.set_xlabel('')
ax1.set_ylabel('Index',fontsize=14)
ax1.xaxis.set_tick_params(labelsize=14)

# %%
fig, ax = plt.subplots(figsize=(10,5))

df_IEF_2008.groupby('Year_Month')['Close'].mean().plot(color='blue',legend=True,label='IEF (yr7-10)')

ax.legend(loc='upper center',fontsize=13)
#ax.set_title('US Treasury Bond (yr7-10)',fontweight='bold',fontsize=20)
ax.set_xlabel('Year_Month',fontsize=14)
ax.set_ylabel('Price($)',fontsize=14,color='blue')
ax=ax.twinx()

df_kospi_2008.groupby('Year_Month')['Close'].mean().plot(color='black',label='KOSPI',legend=True)
#ax.set_title('KOSPI',fontsize=20)
ax.legend(loc='lower center',fontsize=13)
ax.set_xlabel('')
ax.set_ylabel('Index',fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)

# %%
fig, ax = plt.subplots(figsize=(10,5))

df_SPTL_2008.groupby('Year_Month')['Close'].mean().plot(color='blue',legend=True,label='SPTL (yr10<)')

ax.legend(loc='upper center',fontsize=13)
#ax.set_title('US Treasury Bond (yr10<)',fontweight='bold',fontsize=20)
ax.set_xlabel('Year_Month',fontsize=14)
ax.set_ylabel('Price($)',fontsize=14,color='blue')
ax=ax.twinx()

df_kospi_2008.groupby('Year_Month')['Close'].mean().plot(color='black',label='KOSPI',legend=True)
#ax.set_title('KOSPI',fontsize=20)
ax.legend(loc='lower center',fontsize=13)
ax.set_xlabel('')
ax.set_ylabel('Index',fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)

# %%
fig, ax = plt.subplots(figsize=(10,5))

df_SHY_2008.groupby('Year_Month')['Close'].mean().plot(color='blue',legend=True,label='SHY (yr1-3)')

ax.legend(loc='upper center',fontsize=13)
#ax.set_title('US Treasury Bond (yr1-3)',fontweight='bold',fontsize=20)
ax.set_xlabel('Year_Month',fontsize=14)
ax.set_ylabel('Price($)',fontsize=14,color='blue')
ax=ax.twinx()

df_kospi_2008.groupby('Year_Month')['Close'].mean().plot(color='black',label='KOSPI',legend=True)
#ax.set_title('KOSPI',fontsize=20)
ax.legend(loc='lower center',fontsize=13)
ax.set_xlabel('')
ax.set_ylabel('Index',fontsize=14)
ax.xaxis.set_tick_params(labelsize=14)

# %%
fig, ax1 = plt.subplots(figsize=(10,5))

df_IEF_2008.groupby('Year_Month')['Close'].mean().plot(color='green',legend=True,label='IEF (yr7-10)',ax=ax1)
ax1.legend(loc='lower center',fontsize=13)
ax1.set_title('US Treasury Bond + KOSPI',fontweight='bold',fontsize=20)
ax1.xaxis.set_tick_params(labelsize=12)
ax1.set_xlabel('Year_Month',fontsize=14)
ax1.set_ylabel('Price($)',fontsize=14)

ax2=ax1.twinx()

df_SPTL_2008.groupby('Year_Month')['Close'].mean().plot(color='orange',legend=True,label='SPTL (yr10<)',ax=ax2)
ax2.legend(loc='lower right',fontsize=13)

ax3=ax2.twinx()

df_kospi_2008.groupby('Year_Month')['Close'].mean().plot(color='red',label='KOSPI',legend=True,linewidth=5,ax=ax3)
ax3.legend(loc='upper center',fontsize=13)
ax3.set_ylabel('Index_KOSPI',fontsize=14)
# Out:
# Text(0, 0.5, 'Index_KOSPI')

# %%
fig, ax3 = plt.subplots(figsize=(10,5))

df_SHY_2008.groupby('Year_Month')['Close'].mean().plot(color='blue',ax=ax3,legend=True,label='SHY (yr1-3)')
df_IEF_2008.groupby('Year_Month')['Close'].mean().plot(color='green',ax=ax3,legend=True,label='IEF (yr7-10)')
ax3.legend(loc='upper left',fontsize=13)
ax3.set_title('US Treasury Bond Comparison (Duration)',fontweight='bold',fontsize=20)
ax3.set_xlabel('Year_Month',fontsize=14)
ax3.set_ylabel('Price($)_SHY/IEF',fontsize=14)
ax4=ax3.twinx()
df_SPTL_2008.groupby('Year_Month')['Close'].mean().plot(color='orange',ax=ax4,legend=True,label='SPTL (yr10<)')
ax4.legend(loc='upper center',fontsize=13)
ax4.set_ylabel('Price($)_SPTL',fontsize=13)
# Out:
# Text(0, 0.5, 'Price($)_SPTL')
